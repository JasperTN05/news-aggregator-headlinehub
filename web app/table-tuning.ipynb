# %% [markdown]
# ## Table tuning

# %%
import pyforest

# %%
import datetime

# %%
df = pd.read_csv("./datasets/all_articles.csv")
try:
    df.drop("Unnamed: 0", axis=1, inplace=True)
except Exception:
    df = df

# %%
df["Readability"].describe()
# Out:
# count    2499.000000
# mean       10.022776
# std         1.973842
# min         2.488939
# 25%         8.776572
# 50%        10.203113
# 75%        11.398965
# max        16.098391
# Name: Readability, dtype: float64

# %%
df["Date"] = pd.to_datetime(df["Date"])
df["Date"]
# Out:
# 0      2023-12-08 03:06:00
# 1      2023-12-08 02:44:00
# 2      2023-12-08 02:38:00
# 3      2023-12-08 00:01:00
# 4      2023-12-07 22:58:00
#                ...
# 2494   2023-11-27 18:37:00
# 2495   2023-11-27 17:11:00
# 2496   2023-11-27 15:15:00
# 2497   2023-11-27 13:53:00
# 2498   2023-11-27 09:16:00
# Name: Date, Length: 2499, dtype: datetime64[ns]

# %%
df["Author"].fillna("not specified", inplace=True)

# %%
df["Day"] = df["Date"].apply(lambda x: x.date())

# %%
df = df[df['Date'] > datetime(2023, 11, 1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = df[df['Date'] > datetime(2023, 11, 1)]
#
# TypeError: 'module' object is not callable

# %%
df.to_csv("./datasets/all_articles.csv", index=False)

# %% [markdown]
# ## Cat Tables

# %%
politics = df[df["cat_label"]=="Politics"]
politics.sort_values(by="Date", ascending=False, inplace=True)
politics.reset_index(drop=True, inplace=True)
politics.to_csv("./streamlit\data/politics_df.csv", index=False)
politics.head(60)
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_34892\737885819.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   politics.sort_values(by="Date", ascending=False, inplace=True)
#              Source                                              Title  \
# 0               CNN  Details emerge about UNLV gunman who killed 3 ...
# 1               NPR  House votes to censure Rep. Jamaal Bowman for ...
# 2               CNN  Hong Kong and Saudi Arabia want to do more bus...
# 3               ABC  UNLV gunman was unemployed professor who had 1...
# 4               ABC  Houston has a population that's young. Its nex...
# 5               ABC  Federal judge poised to prohibit separating mi...
# 6               ABC  Stock market today: Asian shares are mostly hi...
# 7               CNN  Man accused of firing shotgun outside synagogu...
# 8               ABC  High-profile attacks on Derek Chauvin and Larr...
# 9               ABC  Census Bureau wants to change how it asks abou...
# 10              CNN  How the impasse over Ukraine aid could have cr...
# 11              ABC  Michigan school shooting victims to speak as t...
# 12              ABC  Drought vs deluge: Florida's unusual rainfall ...
# 13              CNN  A Texas judge ruled a pregnant woman who sued ...
# 14              CNN  Hunter Biden faces nine criminal charges in fe...
# 15              ABC  Suspect in UNLV shooting had more than 150 rou...
# 16              ABC  UNLV shooting suspect Anthony Polito applied f...
# 17              CNN  House votes to censure Democratic Rep. Jamaal ...
# 18              CNN  READ: Hunter Biden indictment in federal tax case
# 19              CNN  A deluge of violent messages: How a surge in t...
# 20         Fox News  Truck crash disrupts Christmas parade in Calif...
# 21              CNN  Major donor calls on UPenn president to resign...
# 22              CNN  UNLV gunman sent letters to university personn...
# 23              ABC  Special counsel files 9 tax-related charges ag...
# 39              0.111982    12.025678    0.417594            0  2023-12-07
# 40              0.249811    10.448561    0.445183            0  2023-12-07
# 41              0.000000    12.730000    0.383272            0  2023-12-07
# 42              0.067431    10.258775    0.412358            0  2023-12-07
# 43              0.180745     8.205200    0.334702            0  2023-12-07
# 44              0.078844    12.415282    0.395450            0  2023-12-07
# 45              0.256337     9.800957    0.460250            0  2023-12-07
# 46              0.155602     9.373139    0.408036            0  2023-12-07
# 47              0.236220    10.455556    0.521389            0  2023-12-07
# 48              0.431655    12.718227    0.358956            0  2023-12-07
# 49              0.000000    14.039333    0.470000            0  2023-12-07
# 50              0.000000     8.699852    0.445985            0  2023-12-07
# 51              0.174995    11.932434    0.433569            0  2023-12-07
# 52              0.313808    10.209600    0.417823            0  2023-12-07
# 53              0.078864    11.675644    0.441315            0  2023-12-07
# 54              0.394218     9.658652    0.397302            0  2023-12-07
# 55              0.000000    11.217692    0.292017            0  2023-12-07
# 56              0.141956    10.538878    0.474356            0  2023-12-07
# 57              0.089874     9.453711    0.552661            0  2023-12-07
# 58              0.411603    10.896953    0.307911            0  2023-12-07
# 59              0.000000    14.045194    0.459630            0  2023-12-07

# %%
entertainment = df[df["cat_label"]=="Entertainment and Lifestyle"]
entertainment.sort_values(by="Date", ascending=False, inplace=True)
entertainment.reset_index(drop=True, inplace=True)
entertainment.to_csv("./streamlit\data/entertainment_df.csv", index=False)
entertainment.shape
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_34892\1355178556.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entertainment.sort_values(by="Date", ascending=False, inplace=True)
# (441, 17)

# %%
international = df[df["cat_label"]=="International News"]
international.sort_values(by="Date", ascending=False, inplace=True)
international.to_csv("./streamlit\data/international_df.csv", index=False)
international.shape
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_34892\1161181721.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   international.sort_values(by="Date", ascending=False, inplace=True)
# (367, 17)

# %%
sports = df[df["cat_label"]=="Sports"]
sports.sort_values(by="Date", ascending=False, inplace=True)
sports.to_csv("./streamlit\data/sports_df.csv", index=False)
sports.shape
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_34892\1902612614.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sports.sort_values(by="Date", ascending=False, inplace=True)
# (262, 17)

# %%
buisness = df[df["cat_label"]=="Business and Economy"]
buisness.sort_values(by="Date", ascending=False, inplace=True)
buisness.to_csv("./streamlit\data/buisness_df.csv", index=False)
buisness.shape
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_34892\2219450130.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buisness.sort_values(by="Date", ascending=False, inplace=True)
# (53, 17)

# %%
climate = df[df["cat_label"]=="Climate and Environment"]
climate.sort_values(by="Date", ascending=False, inplace=True)
climate.to_csv("./streamlit\data/climate_df.csv", index=False)
climate.shape
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_34892\1846192144.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   climate.sort_values(by="Date", ascending=False, inplace=True)
# (37, 17)

# %%
health_tech = df[df["cat_label"]=="Health | Science | Technology"]
health_tech.sort_values(by="Date", ascending=False, inplace=True)
health_tech.to_csv("./streamlit\data/health_tech_df.csv", index=False)
health_tech.shape
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_34892\366147441.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   health_tech.sort_values(by="Date", ascending=False, inplace=True)
# (48, 17)

# %%
justice = df[df["cat_label"]=="Law and Justice"]
justice.sort_values(by="Date", ascending=False, inplace=True)
justice.to_csv("./streamlit\data/justice_df.csv", index=False)
justice.shape
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_34892\1208379349.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   justice.sort_values(by="Date", ascending=False, inplace=True)
# (26, 17)

# %% [markdown]
# ## Testing Suggestion Algorithm

# %%
from datetime import datetime

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
filtered_df = df[df['Date'] > datetime(2023, 11, 22)]  # clearing outliers before normalizing

# %%
u_bound = filtered_df["sensationalism_score"].quantile(0.85)    # clearing outliers again
filtered_df_2 = filtered_df[filtered_df["sensationalism_score"]<u_bound]
filtered_df_2    # keeping index to merge again in the end
# Out:
#                Source                                              Title  \
# 1                 CNN  Azerbaijan and Armenia agree to prisoner swap ...
# 2                 CNN  Italy quits Belt and Road plan as Europe rethi...
# 3                 CNN  How the impasse over Ukraine aid could have cr...
# 4                 CNN  ‘Laws need to change’: Stella McCartney calls ...
# 5                 CNN  READ: Hunter Biden indictment in federal tax case
# ...               ...                                                ...
# 2494  Chicago Tribune  More than four dozen file to run for county of...
# 2495  Chicago Tribune  Construction on Brighton Park migrant camp to ...
# 2496  Chicago Tribune  Three wounded in Dixmoor bar shooting, homicid...
# 2497  Chicago Tribune  Foxtrot will merge with Dom’s in specialty gro...
# 2498  Chicago Tribune  One teen dead, one injured in Sunday shootings...
#
#                     Date                                 Author  \
# 1    2023-12-08 02:44:00                           Angela Dewan
# 2    2023-12-08 02:38:00                        Simone McCarthy
# 3    2023-12-08 00:01:00                      Stephen Collinson
# 4    2023-12-07 22:58:00                           Christy Choi
# 5    2023-12-07 22:45:00                              CNN staff
# ...                  ...                                    ...
# 2494 2023-11-27 18:37:00                              A.D. Quig
# 2495 2023-11-27 17:11:00  Alice Yin, Nell Salzman, Dan Petrella
# 2496 2023-11-27 15:15:00                             Mike Nolan
# 2497 2023-11-27 13:53:00                           Talia Soglin
# 2498 2023-11-27 09:16:00                        Rebecca Johnson
#
#                                                    Text  Text lenght  \
# 1     Azerbaijan and Armenia have agreed to a prison...         3408
# 2     Italy, the only G7 country to join China’s fla...         4743
# 3     America’s paralyzing political estrangement ma...        10601
# 4     Stella McCartney has called on world leaders t...         4517
# 5     Hunter Biden has been charged with nine crimin...          535
# ...                                                 ...          ...
# 2494  On the first day political dreams became more ...         5219
# 2495  Chicago’s first government-run tent encampment...         9436
# 2496  Dixmoor police are investigating a shooting ea...         1974
# 2497  Chicago-based grocery startups Foxtrot and Dom...         3662
# 2498  One teenager is dead and another injured in se...          980
#
#                                                     URL  \
# 1     https://www.cnn.com/2023/12/08/europe/azerbaij...
# 2     https://www.cnn.com/2023/12/08/china/italy-bel...
# 2497              0.000000     9.380484    0.413551            0  2023-11-27
# 2498              0.000000    11.750465    0.266667            0  2023-11-27
#
# [2089 rows x 17 columns]

# %%
def flip_column(col):
    return -col

def rank_by_target(column, target):
    differences = abs(column - target)
    ranked_values = differences.rank(method='min', ascending=True)
    return ranked_values

# %%
import pandas as pd
# creating dataframe for features to use for measuring
df_test = filtered_df_2[["Date", "sentiment_score", "sensationalism_score", "Readability", "bias_score", "isClickbait"]]
df_test["Date"] = pd.to_datetime(df_test["Date"])
df_test["Date"] = (df_test['Date'] - pd.Timestamp("1970-01-01")) // pd.Timedelta('1s')  # dates to numeric

cat_dummies = pd.get_dummies(filtered_df_2["cat_label"])   # dummies for categories
df_new = pd.concat([df_test, cat_dummies], axis=1)         # concat measure with category dummies


df_new["sensationalism_score"] = flip_column(df_new["sensationalism_score"])   # reward values that are closer to 0
df_new["bias_score"] = flip_column(df_new["bias_score"])                       # reward values that are closer to 0
df_new["isClickbait"] = flip_column(df_new["isClickbait"])                      # reward values that are closer to 0
df_new["sentiment_score"] = rank_by_target(df_new["sentiment_score"],0)         # reward values that are closer to 0
df_new["Readability"] = rank_by_target(df_new["Readability"],10)                # reward values that are closer to 10 (chosen optimal readability)
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_34892\4254985870.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test["Date"] = pd.to_datetime(df_test["Date"])
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_34892\4254985870.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test["Date"] = (df_test['Date'] - pd.Timestamp("1970-01-01")) // pd.Timedelta('1s')  # dates to numeric

# %%
df_normalized = (df_new - df_new.min()) / (df_new.max() - df_new.min())   # normalizing DataFrame
df_normalized.describe()                                                 # checking distributions
# Out:
#               Date  sentiment_score  sensationalism_score  Readability  \
# count  2089.000000      2089.000000           2089.000000  2089.000000
# mean      0.700284         0.499832              0.677388     0.499996
# std       0.191999         0.288732              0.296455     0.288882
# min       0.000000         0.000000              0.000000     0.000000
# 25%       0.531447         0.250000              0.445657     0.250000
# 50%       0.742847         0.500000              0.713163     0.500000
# 75%       0.847074         0.750000              1.000000     0.750000
# max       1.000000         1.000000              1.000000     1.000000
#
#         bias_score  isClickbait  Business and Economy  \
# count  2089.000000  2089.000000           2089.000000
# mean      0.405561     0.975108              0.024414
# std       0.116657     0.155834              0.154366
# min       0.000000     0.000000              0.000000
# 25%       0.335231     1.000000              0.000000
# 50%       0.398589     1.000000              0.000000
# 75%       0.469922     1.000000              0.000000
# max       1.000000     1.000000              1.000000
#
#        Climate and Environment  Entertainment and Lifestyle  \
# count               2089.00000                  2089.000000
# mean                   0.01484                     0.177118
# std                    0.12094                     0.381860
# min                    0.00000                     0.000000
# 25%                    0.00000                     0.000000
# 50%                    0.00000                     0.000000
# 75%                    0.00000                     0.000000
# max                    1.00000                     1.000000
#
#        Health | Science | Technology  International News  Law and Justice  \
# count                    2089.000000         2089.000000      2089.000000
# mean                        0.020584            0.123983         0.011010
# std                         0.142021            0.329641         0.104375
# min                         0.000000            0.000000         0.000000
# 25%                         0.000000            0.000000         0.000000
# 50%                         0.000000            0.000000         0.000000
# 75%                         0.000000            0.000000         0.000000
# max                         1.000000            1.000000         1.000000
#
#           Politics       Sports
# count  2089.000000  2089.000000
# mean      0.512207     0.115845
# std       0.499971     0.320115
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       1.000000     0.000000
# 75%       1.000000     0.000000
# max       1.000000     1.000000

# %%
# Define weights for each metric
weights = {
    "Date": 0.25,
    "Readability": 0.15,
    "sentiment_score": 0.1,
    "bias_score": 0.1,
    "isClickbait": 0.1,
    "sensationalism_score": 0.1,
    "Business and Economy": 0.03,
    "Climate and Environment": 0.02,
    "Health | Science | Technology": 0.02,
    "International News" : 0.03,
    "Law and Justice": 0.02,
    "Politics": 0.05,
    "Sports":0.03
}

df["combined_score"] = (df_normalized * pd.Series(weights)).sum(axis=1)   # final measurement

# Rank articles based on the combined score
df_ranked = df.sort_values(by="combined_score", ascending=False)

# %%
df_ranked.to_csv("./datasets/ranked_df.csv", index=False)

# %%
df.drop("combined_score", axis=1, inplace=True)

# %% [markdown]
# ## Profile tables

# %%
basis_df = df[["Date", "Text lenght", "sentiment_score", "sensationalism_score", "Readability","bias_score", "isClickbait"]]
basis_df["Date"] = pd.to_datetime(basis_df["Date"])
basis_df = basis_df[basis_df['Date'] > datetime(2023, 11, 24)]  
basis_df["Date"] = (basis_df['Date'] - pd.Timestamp("1970-01-01")) // pd.Timedelta('1s')  # dates to numeric
basis_df = basis_df[basis_df["Text lenght"]<100000]
basis_df
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_34892\3394357285.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basis_df["Date"] = pd.to_datetime(basis_df["Date"])
#             Date  Text lenght  sentiment_score  sensationalism_score  \
# 0     1702004760         3999         -0.98715              0.450113
# 1     1702003440         3408          0.94895              0.000000
# 2     1702003080         4743          0.52270              0.063251
# 3     1701993660        10601         -0.99320              0.198095
# 4     1701989880         4517          0.31345              0.066416
# ...          ...          ...              ...                   ...
# 2494  1701110220         5219          0.98125              0.057482
# 2495  1701105060         9436         -0.24030              0.158966
# 2496  1701098100         1974         -0.98160              0.000000
# 2497  1701093180         3662          0.97315              0.000000
# 2498  1701076560          980         -0.94860              0.000000
#
#       Readability  bias_score  isClickbait
# 0       10.987507    0.321686            0
# 1       12.742564    0.356000            0
# 2       12.224010    0.359584            0
# 3        9.764189    0.387461            0
# 4       10.510381    0.451278            0
# ...           ...         ...          ...
# 2494    12.249649    0.344288            0
# 2495    11.441750    0.447383            0
# 2496    11.510227    0.249487            0
# 2497     9.380484    0.413551            0
# 2498    11.750465    0.266667            0
#
# [2453 rows x 7 columns]

# %%
# weights in depth explorer
weights_ide = {
    "Date": 0.2,
    "Text lenght":0.3,
    "Readability": 0.15,
    "sentiment_score": 0.05,
    "bias_score": 0.1,
    "isClickbait": 0.1,
    "sensationalism_score": 0.1,
}

# %%
# In-Depth Explorer
filter_ide = basis_df.copy()

# text length
filter_ide = filter_ide[filter_ide["Text lenght"]>1500]  # long

# sentiment score
T_sentiment = 0.3   # neutral to positive
filter_ide["sentiment_score"] =  rank_by_target(filter_ide["sentiment_score"],T_sentiment)

#readability
T_readability = basis_df["Readability"].quantile(0.75)  # moderate to challenging
filter_ide["Readability"] =  rank_by_target(filter_ide["Readability"],T_readability)
filter_ide["Readability"] = flip_column(filter_ide["Readability"]) 

#sensationalism score
T_sensationalism = basis_df["sensationalism_score"].quantile(0.1) #low
filter_ide["sensationalism_score"] =  rank_by_target(filter_ide["sensationalism_score"],T_sensationalism)

# bias score
T_bias = basis_df["bias_score"].quantile(0.25)  # balanced
filter_ide["bias_score"] =  rank_by_target(filter_ide["bias_score"],T_bias)

# clickbait check 
filter_ide["isClickbait"] = flip_column(filter_ide["isClickbait"])   # no clickbait

ide_normalized = (filter_ide - filter_ide.min()) / (filter_ide.max() - filter_ide.min())   # normalizing DataFrame
df["combined_score"] = (ide_normalized * pd.Series(weights_ide)).sum(axis=1)   # final measurement
ide_ranked = df.sort_values(by="combined_score", ascending=False)
df.drop("combined_score", axis=1, inplace=True)
ide_ranked.head()
# Out:
#               Source                                              Title  \
# 87               CNN                  December 7, 2023 Israel-Hamas war
# 812   New York Times  Israel-Hamas WarBiden Condemns Rapes by Hamas ...
# 1712             CNN                  December 1, 2023 Israel-Hamas war
# 78               CNN  A deluge of violent messages: How a surge in t...
# 235   New York Times  Israel-Hamas WarRelief Effort Falters in South...
#
#                     Date                                             Author  \
# 87   2023-12-08 00:00:00                                   Kathleen Magramo
# 812  2023-12-05 19:59:00  Michael D. Shear, Liam Stack, Nick Cumming-Bru...
# 1712 2023-12-02 00:05:00                                   Tara Subramaniam
# 78   2023-12-07 22:33:00                                         Rob Kuznia
# 235  2023-12-08 02:42:00  Victoria Kim, Gaya Gupta, Isabel Kershner, Aar...
#
#                                                    Text  Text lenght  \
# 87    Our live coverage of the Israel-Hamas war has ...        61388
# 812   ‘Worse by the hour’: The W.H.O. warns of the l...        55256
# 1712  Our coverage of the Israel-Hamas war has moved...        59104
# 78    (CNN) – By the time the FBI first showed up at...        30616
# 235   Israel says hundreds of suspects, including Ha...        22036
#
#                                                     URL  \
# 87    https://www.cnn.com/middleeast/live-news/israe...
# 812   https://www.nytimes.com//live/2023/12/05/world...
# 1712  https://www.cnn.com/middleeast/live-news/israe...
# 78    https://www.cnn.com/2023/12/07/politics/threat...
# 235   https://www.nytimes.com//live/2023/12/08/world...
#
#                                                imageURL           cat_label  \
# 87    https://media.cnn.com/api/v1/images/stellar/pr...  International News
# 812   https://tse2.mm.bing.net/th?id=OIP.jVot1lhu9Pm...  International News
# 1712  https://media.cnn.com/api/v1/images/stellar/pr...  International News
# 78    https://media.cnn.com/api/v1/images/stellar/pr...            Politics
# 235   https://static01.nyt.com/images/2023/12/08/mul...  International News
#
#                                               sourceURL  \
# 87    https://tse2.mm.bing.net/th?id=OIP.W3gWO3a5Tnx...
# 812   https://tse2.mm.bing.net/th?id=OIP.jVot1lhu9Pm...
# 1712  https://tse2.mm.bing.net/th?id=OIP.W3gWO3a5Tnx...
# 78    https://tse2.mm.bing.net/th?id=OIP.W3gWO3a5Tnx...
# 235   https://tse2.mm.bing.net/th?id=OIP.jVot1lhu9Pm...
#
#                                              clean_blob  sentiment_score  \
# 87    khan raise fattah discretion survivor hansler ...         -0.99945
# 812   account demirjianin town offender medical prop...         -0.99975
# 1712  lie ground make occupation urge palestinian he...         -0.99955
# 78    culprit cocktail raise vague incarcerate lion ...         -0.99970
# 235   country farther khan boxerman enclave conditio...         -0.99860
#
#       sensationalism_score  Readability  bias_score  isClickbait         Day  \
# 87                0.307878    11.803292    0.313432            0  2023-12-08
# 812               0.276893    10.759374    0.360183            0  2023-12-05
# 1712              0.299472    11.984970    0.349385            0  2023-12-02
# 78                0.274366    10.398540    0.403832            0  2023-12-07
# 235               0.340352    10.693127    0.306087            0  2023-12-08
#
#       combined_score
# 87          0.892899
# 812         0.782096
# 1712        0.753666
# 78          0.705456
# 235         0.687500

# %%
ide_ranked.to_csv("./streamlit/data/In-DepthExplorer.csv", index=False)

# %%
# weights in quick briefing
weights_qb = {
    "Date": 0.25,
    "Text lenght":0.15,
    "Readability": 0.15,
    "sentiment_score": 0.15,
    "bias_score": 0.1,
    "isClickbait": 0.1,
    "sensationalism_score": 0.1,
}

# %%
# Quick Briefing
filter_qb = basis_df.copy()

# text length 
filter_qb = filter_qb[filter_qb["Text lenght"]<6500]   # short
filter_qb["Text lenght"] = flip_column(filter_qb["Text lenght"])

# sentiment score
T_sentiment = 0   # neutral
filter_qb["sentiment_score"] =  rank_by_target(filter_qb["sentiment_score"],T_sentiment)
filter_qb["sentiment_score"] = flip_column(filter_qb["sentiment_score"])   

#readability
T_readability = basis_df["Readability"].quantile(0.25)  # high
filter_qb["Readability"] =  rank_by_target(filter_qb["Readability"],T_readability)
filter_qb["Readability"] = flip_column(filter_qb["Readability"])   

#sensationalism score
T_sensationalism = basis_df["sensationalism_score"].quantile(0.45) # moderate
filter_qb["sensationalism_score"] =  rank_by_target(filter_qb["sensationalism_score"],T_sensationalism)
filter_qb["sensationalism_score"] = flip_column(filter_qb["sensationalism_score"])   

# bias score
T_bias = basis_df["bias_score"].quantile(0.2)  # balanced
filter_qb["bias_score"] =  rank_by_target(filter_qb["bias_score"],T_bias)
filter_qb["bias_score"] = flip_column(filter_qb["bias_score"])   

# clickbait check 
filter_qb["isClickbait"] = flip_column(filter_qb["isClickbait"])   # no clickbait

qb_normalized = (filter_qb - filter_qb.min()) / (filter_qb.max() - filter_qb.min())   # normalizing DataFrame
df["combined_score"] = (qb_normalized * pd.Series(weights_qb)).sum(axis=1)   # final measurement
qb_ranked = df.sort_values(by="combined_score", ascending=False)
df.drop("combined_score", axis=1, inplace=True)
qb_ranked.head()
# Out:
#          Source                                              Title  \
# 607         CNN  Spectator dies after ‘medical emergency’ durin...
# 110    Fox News  Comer, Jordan threaten to hold Hunter Biden in...
# 713         ABC              Deals & Steals on gifts for everyone!
# 1117  USA TODAY  Who qualified for the next GOP debate? These R...
# 126    Fox News  Yankees could attract more stars if they dropp...
#
#                     Date                       Author  \
# 607  2023-12-05 11:54:00                  Jill Martin
# 110  2023-12-06 12:45:00               Brooke Singman
# 713  2023-12-05 17:56:00  Stefan Joyce and Mason Leib
# 1117 2023-12-05 01:13:27               Sudiksha Kochi
# 126  2023-12-07 20:32:00                   Ryan Morik
#
#                                                    Text  Text lenght  \
# 607   A spectator died during an NBA game between th...         1103
# 110   FIRST ON FOX: House Oversight Committee Chairm...         2698
# 713   A video obtained by ABC News via the then stud...         2007
# 1117  WASHINGTON — The fourth Republican primary deb...         1540
# 126   The New York Yankees are the most famous sport...         2264
#
#                                                     URL  \
# 607   https://www.cnn.com/2023/12/05/sport/nba-fan-d...
# 110   https://www.foxnews.com/politics/comer-jordan-...
# 713   https://www.goodmorningamerica.com/news/story/...
# 1117  https://eu.usatoday.com/story/news/politics/el...
# 126   https://www.foxnews.com/sports/yankees-bring-m...
#
#                                                imageURL cat_label  \
# 607   https://media.cnn.com/api/v1/images/stellar/pr...    Sports
# 110   https://a57.foxnews.com/static.foxnews.com/fox...  Politics
# 713   https://s.abcnews.com/images/GMA/promposal-ht-...  Politics
# 1117  https://www.gannett-cdn.com/authoring/authorin...  Politics
# 126   https://a57.foxnews.com/static.foxnews.com/fox...    Sports
#
#                                               sourceURL  \
# 607   https://tse2.mm.bing.net/th?id=OIP.W3gWO3a5Tnx...
# 110   https://tse1.mm.bing.net/th?id=OIP.cgyUI9sP8zj...
# 713   https://tse1.mm.bing.net/th?id=OIP.KAIEmdZnuss...
# 1117  https://tse4.mm.bing.net/th?id=OIP.SY6y2UDBYYu...
# 126   https://tse1.mm.bing.net/th?id=OIP.cgyUI9sP8zj...
#
#                                              clean_blob  sentiment_score  \
# 607   emergency forward administer statement tragica...         -0.38500
# 110   hunter testifies treatment november vow defend...         -0.52550
# 713   drive instant girlfriend faster hour proposal ...         -0.68475
# 1117  nikki unique biden burgum florida week announc...          0.27695
# 126   player cmon cashman brian steinbrenner upper c...          0.70065
#
#       sensationalism_score  Readability  bias_score  isClickbait         Day  \
# 607               0.000000     8.969444    0.330716            0  2023-12-05
# 110               0.111193     9.244436    0.318168            0  2023-12-06
# 713               0.149477     8.790457    0.354141            0  2023-12-05
# 1117              0.000000     8.389116    0.350808            0  2023-12-05
# 126               0.132509     8.796372    0.428756            0  2023-12-07
#
#       combined_score
# 607         0.858417
# 110         0.846506
# 713         0.846412
# 1117        0.836886
# 126         0.833586

# %%
qb_ranked.to_csv("./streamlit/data/QuickBriefing.csv", index=False)

# %%
# weights positive vibes
weights_pv = {
    "Date": 0.25,
    "Text lenght":0.15,
    "Readability": 0.15,
    "sentiment_score": 0.2,
    "bias_score": 0.15,
    "isClickbait": 0,
    "sensationalism_score": 0.1,
}

# %%
# positive vibes
filter_pv = basis_df.copy()

# text length 
T_length = filter_pv["Text lenght"].median()   # moderate
filter_pv["Text lenght"] = rank_by_target(filter_pv["Text lenght"], T_length)

# sentiment score
T_sentiment = 0.85   # positive
filter_pv["sentiment_score"] =  rank_by_target(filter_pv["sentiment_score"],T_sentiment)
filter_pv["sentiment_score"] =  flip_column(filter_pv["sentiment_score"])

#readability
T_readability = basis_df["Readability"].quantile(0.4)  # moderate to high
filter_pv["Readability"] =  rank_by_target(filter_pv["Readability"],T_readability)
filter_qb["Readability"] = flip_column(filter_qb["Readability"])   

#sensationalism score
T_sensationalism = basis_df["sensationalism_score"].quantile(0.6) # moderate to high
filter_pv["sensationalism_score"] =  rank_by_target(filter_pv["sensationalism_score"],T_sensationalism)
filter_qb["sensationalism_score"] = flip_column(filter_qb["sensationalism_score"])   

# bias score
T_bias = basis_df["bias_score"].quantile(0.2)  # balanced
filter_pv["bias_score"] =  rank_by_target(filter_pv["bias_score"],T_bias)

# clickbait check 
filter_pv["isClickbait"] = 0   # no clickbait

pv_normalized = (filter_pv - filter_pv.min()) / (filter_pv.max() - filter_pv.min())   # normalizing DataFrame
df["combined_score"] = (pv_normalized * pd.Series(weights_pv)).sum(axis=1)   # final measurement
pv_ranked = df.sort_values(by="combined_score", ascending=False)
df.drop("combined_score", axis=1, inplace=True)
pv_ranked.head()
# Out:
#               Source                                              Title  \
# 613              CNN        Sean Astin is fine with a ‘nepo baby’ label
# 1523             ABC  Vermont sinks Yale with buzzer-beating four-po...
# 359              CNN  Angelina Jolie describes Hollywood as ‘shallow...
# 508   New York Times  Pantone’s Color of the Year for 2024 Is Peach ...
# 892              CNN  Will Smith talks about the ‘monster’ of fame a...
#
#                     Date               Author  \
# 613  2023-12-05 10:27:00      Marianne Garvey
# 1523 2023-12-03 08:29:00             ABC News
# 359  2023-12-06 10:06:00  Lisa Respers France
# 508  2023-12-07 08:30:00      The Styles Desk
# 892  2023-12-04 12:41:00      Marianne Garvey
#
#                                                    Text  Text lenght  \
# 613   Actor Sean Astin acknowledges a little nepotis...         1480
# 1523  The Catamounts inbounded the ball from underne...         1277
# 359   Angelina Jolie says she wouldn’t be an actress...         2062
# 508   By The Styles DeskOn Thursday, Pantone announc...          685
# 892   Will Smith is reflecting on the dangers of fam...         1139
#
#                                                     URL  \
# 613   https://www.cnn.com/2023/12/05/entertainment/s...
# 1523  https://abcnews.go.com/Sports/vermont-sinks-ya...
# 359   https://www.cnn.com/2023/12/06/entertainment/a...
# 508   https://www.nytimes.com//2023/12/07/style/pant...
# 892   https://www.cnn.com/2023/12/04/entertainment/w...
#
#                                                imageURL  \
# 613   https://media.cnn.com/api/v1/images/stellar/pr...
# 1523  ......
# 359   https://media.cnn.com/api/v1/images/stellar/pr...
# 508   https://static01.nyt.com/images/2023/12/07/fas...
# 892   https://media.cnn.com/api/v1/images/stellar/pr...
#
#                         cat_label  \
# 613   Entertainment and Lifestyle
# 1523                       Sports
# 359   Entertainment and Lifestyle
# 508   Entertainment and Lifestyle
# 892   Entertainment and Lifestyle
#
#                                               sourceURL  \
# 613   https://tse2.mm.bing.net/th?id=OIP.W3gWO3a5Tnx...
# 1523  https://tse1.mm.bing.net/th?id=OIP.KAIEmdZnuss...
# 359   https://tse2.mm.bing.net/th?id=OIP.W3gWO3a5Tnx...
# 508   https://tse2.mm.bing.net/th?id=OIP.jVot1lhu9Pm...
# 892   https://tse2.mm.bing.net/th?id=OIP.W3gWO3a5Tnx...
#
#                                              clean_blob  sentiment_score  \
# 613   feel opportunity fortune born rudy stage lotr ...          0.95155
# 1523  tonight vermont bez draw left block aaron unbe...          0.87415
# 359   divorce hear wall actress work angelina live u...          0.94985
# 508   article select world release play announce hum...          0.80700
# 892   continued excite joy stay festival oscar acade...          0.99010
#
#       sensationalism_score  Readability  bias_score  isClickbait         Day  \
# 613               0.405405     4.621170    0.543750            0  2023-12-05
# 1523              0.469851     5.743235    0.621296            0  2023-12-03
# 359               0.436469     5.389011    0.516426            0  2023-12-06
# 508               0.000000     7.157391    0.461637            0  2023-12-07
# 892               0.526778     5.309291    0.523810            0  2023-12-04
#
#       combined_score
# 613         0.858639
# 1523        0.851767
# 359         0.850557
# 508         0.846582
# 892         0.819383

# %%
pv_ranked.to_csv("./streamlit/data/PositiveVibes.csv", index=False)

# %%
# weights positive vibes
weights_bp = {
    "Date": 0.25,
    "Text lenght":0.1,
    "Readability": 0.1,
    "sentiment_score": 0.25,
    "bias_score": 0.2,
    "isClickbait": 0.05,
    "sensationalism_score": 0.1,
}

# %%
# Quick Briefing
filter_bp = basis_df.copy()

# text length 
T_length = filter_bp["Text lenght"].median()   # moderate
filter_bp["Text lenght"] = rank_by_target(filter_bp["Text lenght"], T_length)

# sentiment score
T_sentiment = 0   # neutral
filter_bp["sentiment_score"] =  rank_by_target(filter_bp["sentiment_score"],T_sentiment)
filter_bp["sentiment_score"] = flip_column(filter_bp["sentiment_score"])

#readability
T_readability = basis_df["Readability"].quantile(0.55)  # moderate
filter_bp["Readability"] =  rank_by_target(filter_bp["Readability"],T_readability)

#sensationalism score
T_sensationalism = basis_df["sensationalism_score"].quantile(0.35) # low to moderate
filter_bp["sensationalism_score"] =  rank_by_target(filter_bp["sensationalism_score"],T_sensationalism)

# bias score
T_bias = 0  # low
filter_bp["bias_score"] =  rank_by_target(filter_bp["bias_score"],T_bias)
filter_bp["bias_score"] = flip_column(filter_bp["bias_score"])

# clickbait check 
filter_bp["isClickbait"] = flip_column(filter_bp["isClickbait"])   # no clickbait

pb_normalized = (filter_bp - filter_bp.min()) / (filter_bp.max() - filter_bp.min())   # normalizing DataFrame
df["combined_score"] = (pb_normalized * pd.Series(weights_bp)).sum(axis=1)   # final measurement
bp_ranked = df.sort_values(by="combined_score", ascending=False)
df.drop("combined_score", axis=1, inplace=True)
bp_ranked.head(10)
# Out:
#      Source                                              Title  \
# 265     NPR  Centenarian Pearl Harbor survivors return to h...
# 75      CNN  China’s real estate crisis is coming for its m...
# 137     ABC             AP Week in Pictures: Europe and Africa
# 551     NPR  Palestinians in Chicago mourn loss of family i...
# 1236    ABC  China's Xi welcomes President Alexander Lukash...
# 429     ABC  Centenarian survivors of Pearl Harbor attack a...
# 35      CNN  Paris Hilton explains why she didn’t change he...
# 548     NPR  The Seriousness of America's Latest Homegrown Spy
# 140     ABC  Federal judge poised to prohibit separating mi...
# 441     ABC  Authorities in Alaska suspend search for boy m...
#
#                     Date                                             Author  \
# 265  2023-12-07 19:53:00                               The Associated Press
# 75   2023-12-07 05:17:00                                           Laura He
# 137  2023-12-08 01:22:00                               The Associated Press
# 551  2023-12-06 15:50:00                                  Mohamad ElBardicy
# 1236 2023-12-04 08:43:00                               The Associated Press
://tse1.mm.bing.net/th?id=OIP.KAIEmdZnuss...
#
#                                              clean_blob  sentiment_score  \
# 265   slow cocktail heard visitor historic raise rea...         -0.03155
# 75    country player significantly raise payment spo...          0.00655
# 137   travel cadet image bucharest associate rainfal...         -0.28795
# 551   delay love month prepare case huge toddler dir...         -0.05875
# 1236  increasingly economy opposes exchange country ...          0.10025
# 429   personnel monarch michael fire survivor sits s...         -0.02095
# 35    room nicky change explain traumatize minute op...         -0.30565
# 548   sami louise courtney mary river charge decade ...         -0.13660
# 140   country shelter enter dollar aclu case justice...         -0.37155
# 441   search recover cover volunteer rescue estimate...         -0.17380
#
#       sensationalism_score  Readability  bias_score  isClickbait         Day  \
# 265               0.238727     7.471680    0.273736            0  2023-12-07
# 75                0.287942    11.927434    0.318199            0  2023-12-07
# 137               0.000000    14.948400    0.280556            0  2023-12-08
# 551               0.484541     5.208004    0.394089            0  2023-12-06
# 1236              0.238474    14.745366    0.123077            0  2023-12-04
# 429               0.350536     8.583541    0.323720            0  2023-12-07
# 35                0.257732     6.441606    0.376768            0  2023-12-07
# 548               0.000000     8.767213    0.000000            0  2023-12-06
# 140               0.256739    12.296973    0.317560            0  2023-12-08
# 441               0.456274    11.576824    0.343953            0  2023-12-06
#
#       combined_score
# 265         0.972901
# 75          0.930466
# 137         0.911723
# 551         0.909168
# 1236        0.908421
# 429         0.888764
# 35          0.886591
# 548         0.882199
# 140         0.876972
# 441         0.872853

# %%
bp_ranked.to_csv("./streamlit/data/BalancedPerspektive.csv", index=False)

# %%
# weights in depth analysis
weights_ida = {
    "Date": 0.25,
    "Text lenght":0.15,
    "Readability": 0.15,
    "sentiment_score": 0.15,
    "bias_score": 0.15,
    "isClickbait": 0.1,
    "sensationalism_score": 0.1,
}

# %%
# in depth analysis
filter_ida = basis_df.copy()

# text length 
filter_ida = filter_ida[filter_ida["Text lenght"]>4000]  # long

# sentiment score
T_sentiment = -0.2   # neutral to negative
filter_ida["sentiment_score"] =  rank_by_target(filter_ida["sentiment_score"],T_sentiment)
filter_ida["sentiment_score"] = flip_column(filter_ida["sentiment_score"])

#readability
T_readability = 12 # moderate
filter_ida["Readability"] =  rank_by_target(filter_ida["Readability"],T_readability)
filter_ida["Readability"] = flip_column(filter_ida["Readability"])

#sensationalism score
T_sensationalism = basis_df["sensationalism_score"].quantile(0.35) # low to moderate
filter_ida["sensationalism_score"] =  rank_by_target(filter_ida["sensationalism_score"],T_sensationalism)

# bias score
T_bias = 0.35  # moderate
filter_ida["bias_score"] =  rank_by_target(filter_ida["bias_score"],T_bias)
filter_ida["bias_score"] = flip_column(filter_ida["bias_score"])

# clickbait check 
filter_ida["isClickbait"] = flip_column(filter_ida["isClickbait"])   # no clickbait

ida_normalized = (filter_ida - filter_ida.min()) / (filter_ida.max() - filter_ida.min())   # normalizing DataFrame
df["combined_score"] = (ida_normalized * pd.Series(weights_ida)).sum(axis=1)   # final measurement
ida_ranked = df.sort_values(by="combined_score", ascending=False)
df.drop("combined_score", axis=1, inplace=True)
ida_ranked.head(10)
# Out:
#                Source                                              Title  \
# 87                CNN                  December 7, 2023 Israel-Hamas war
# 812    New York Times  Israel-Hamas WarBiden Condemns Rapes by Hamas ...
# 1712              CNN                  December 1, 2023 Israel-Hamas war
# 75                CNN  China’s real estate crisis is coming for its m...
://tse2.mm.bing.net/th?id=OIP.W3gWO3a5Tnx...
# 75    https://tse2.mm.bing.net/th?id=OIP.W3gWO3a5Tnx...
# 206   https://tse3.explicit.bing.net/th?id=OIP.cysHE...
# 121   https://tse1.mm.bing.net/th?id=OIP.cgyUI9sP8zj...
# 554   https://tse1.mm.bing.net/th?id=OIP.bdQ4hj2mS6u...
# 402   https://tse1.mm.bing.net/th?id=OIP.KAIEmdZnuss...
# 316   https://tse2.mm.bing.net/th?id=OIP.W3gWO3a5Tnx...
# 829   https://tse1.mm.bing.net/th?id=OIP.jw0U2QGUAVS...
#
#                                              clean_blob  sentiment_score  \
# 87    khan raise fattah discretion survivor hansler ...         -0.99945
# 812   account demirjianin town offender medical prop...         -0.99975
# 1712  lie ground make occupation urge palestinian he...         -0.99955
# 75    country player significantly raise payment spo...          0.00655
# 206   rubio heard definitive dozen advisory taxpayer...         -0.22950
# 121   user raise steal send response fascism back id...         -0.06020
# 554   stride case disclosure work behalf oversee add...         -0.01000
# 402   month fire central harder send threaten chance...         -0.94240
# 316   china month aggression enhance smooth gesture ...          0.01760
# 829   fitch increase cheung property lower change mo...         -0.82740
#
#       sensationalism_score  Readability  bias_score  isClickbait         Day  \
# 87                0.307878    11.803292    0.313432            0  2023-12-08
# 812               0.276893    10.759374    0.360183            0  2023-12-05
# 1712              0.299472    11.984970    0.349385            0  2023-12-02
# 75                0.287942    11.927434    0.318199            0  2023-12-07
# 206               0.317412    11.728419    0.400760            0  2023-12-07
# 121               0.253646    11.033716    0.357782            0  2023-12-07
# 554               0.221348    11.972887    0.369215            0  2023-12-06
# 402               0.183599    11.850682    0.337814            0  2023-12-07
# 316               0.111857    11.949965    0.330948            0  2023-12-07
# 829               0.343708    11.764851    0.328181            0  2023-12-05
#
#       combined_score
# 87          0.905110
# 812         0.835078
# 1712        0.835016
# 75          0.829316
# 206         0.812863
# 121         0.812661
# 554         0.811508
# 402         0.789530
# 316         0.789168
# 829         0.788220

# %%
ida_ranked.to_csv("./streamlit/data/InDepthAnalysis.csv", index=False)

# %%
# weights critical thinker
weights_ida = {
    "Date": 0.25,
    "Text lenght":0.15,
    "Readability": 0.1,
    "sentiment_score": 0.0,
    "bias_score": 0.2,
    "isClickbait": 0.05,
    "sensationalism_score": 0.1,
}

# %%
# in depth analysis
filter_ct = basis_df.copy()

# text length 
filter_ct = filter_ct[filter_ct["Text lenght"]>2000]  # long

# sentiment score
filter_ct["sentiment_score"] = 0

#readability
T_readability = 9 # moderate
filter_ct["Readability"] =  rank_by_target(filter_ct["Readability"],T_readability)
filter_ct["Readability"] = flip_column(filter_ct["Readability"])

#sensationalism score
T_sensationalism = basis_df["sensationalism_score"].quantile(0.4) # low to moderate
filter_ct["sensationalism_score"] =  rank_by_target(filter_ct["sensationalism_score"],T_sensationalism)

# bias score
T_bias = 0.5  # moderate
filter_ct["bias_score"] =  rank_by_target(filter_ct["bias_score"],T_bias)
filter_ct["bias_score"] = flip_column(filter_ct["bias_score"])

# clickbait check 
filter_ct["isClickbait"] = flip_column(filter_ct["isClickbait"])   # no clickbait

ct_normalized = (filter_ct - filter_ct.min()) / (filter_ct.max() - filter_ct.min())   # normalizing DataFrame
df["combined_score"] = (ct_normalized * pd.Series(weights_ida)).sum(axis=1)   # final measurement
ct_ranked = df.sort_values(by="combined_score", ascending=False)
df.drop("combined_score", axis=1, inplace=True)
ct_ranked.head(10)
# Out:
#                Source                                              Title  \
# 547               NPR  Israel presses U.N. to investigate charges of ...
# 141               ABC  Stock market today: Asian shares are mostly hi...
# 1034  Washington Post  For Beyoncé and Taylor Swift, the big screen f...
# 552               NPR  Pilots say they're afraid to seek mental healt...
# 227   Washington Post  You need not be a history buff to delight in ‘...
# 243             MSNBC  Making ‘Squid Game’ a reality show ruins the w...
# 221   Washington Post  Ask Sahaj: White boyfriend doesn’t get girlfri...
# 424               ABC  Indonesian maleo conservation faced setbacks d...
# 464          Politico  Biden calls on Congress to pass Ukraine aid: ‘...
# 153               ABC  NBA In-Season Tournament not lacking in the La...
#
#                     Date                                             Author  \
# 547  2023-12-06 17:41:00                                     Becky Sullivan
# 141  2023-12-08 00:28:00                      ZIMO ZHONG AP business writer
# 1034 2023-12-05 05:00:00                                     Chris Richards
# 552  2023-12-06 15:44:00                                          Joel Rose
# 227  2023-12-07 06:00:00                                      Michael Dirda
# 243  2023-12-07 00:16:00                                         Noor Noman
# 221  2023-12-07 09:00:00                                   Sahaj Kaur Kohli
# 424  2023-12-07 00:10:00  EDNA TARIGAN Associated Press and DITA ALANGKA...
# 464  2023-12-06 13:32:00                                 Jennifer Haberkorn
# 153  2023-12-07 21:40:00                     MARK ANDERSON AP sports writer
#
#                                                    Text  Text lenght  \
# 547   Michele Kelemen Editor's note: This story cont...         7339
# 141   HONG KONG -- Asian shares were mostly higher o...         3625
# 1034  For elite pop stars trying to keep their money...         5508
# 552   But he hesitated, because he feared what would...         3966
# 227   “The Book of Kells,” “The Lindisfarne Gospels”...         8589
# 243   “Squid Game: The Challenge,” whose final episo...         6063
# 221   Hi Sahaj: I am 44 and Black/White mixed; my bo...         4369
# 424   MAMUJU, Indonesia -- A pair of tall birds with...         7267
# 464   President Joe Biden on Wednesday said he is wi...         2558
# 153   LAS VEGAS -- When league officials decided to ...         2800
#
#                                                     URL  \
# 547   https://www.npr.org/2023/12/06/1217668564/isra...
# 141   https://abcnews.go.com/Business/wireStory/stoc...
# 1034  https://www.washingtonpost.com/entertainment/m...
# 552   https://www.npr.org/2023/12/06/1217591486/pilo...
# 227   https://www.washingtonpost.com/books/2023/12/0...
# 243   https://www.msnbc.com/opinion/msnbc-opinion/ne...
# 221   https://www.washingtonpost.com/advice/2023/12/...
# 424   https://abcnews.go.com/International/wireStory...
# 464   https://www.politico.com/news/2023/12/06/biden...
# 153   https://abcnews.go.com/Sports/wireStory/nba-se...
#
#                                                imageURL  \
# 547   https://media.npr.org/assets/img/2012/01/03/mi...
# 141   https://i.abcnewsfe.com/a/2d6e8624-3bb0-4f9a-8...
# 1034  https://tse3.explicit.bing.net/th?id=OIP.cysHE...
# 552   https://tse4.mm.bing.net/th?id=OIP.VhogjnWRzUb...
# 227   https://tse3.explicit.bing.net/th?id=OIP.cysHE...
# 243   https://tse4.mm.bing.net/th?id=OIP.0QnXrS2STCJ...
# 221   https://tse3.explicit.bing.net/th?id=OIP.cysHE...
# 424   https://i.abcnewsfe.com/a/9371256c-4d98-43aa-8...
# 464   https://tse1.mm.bing.net/th?id=OIP.GNggW5ET63W...
# 153   https://i.abcnewsfe.com/a/38cd19d4-a350-42de-a...
#
#                         cat_label  \
# 547                      Politics
# 141                      Politics
# 1034  Entertainment and Lifestyle
# 552                      Politics
# 227   Entertainment and Lifestyle
# 243                      Politics
# 221   Entertainment and Lifestyle
# 424            International News
# 464                      Politics
# 153                        Sports
#
#                                               sourceURL  \
# 547   https://tse4.mm.bing.net/th?id=OIP.VhogjnWRzUb...
# 141   https://tse1.mm.bing.net/th?id=OIP.KAIEmdZnuss...
# 1034  https://tse3.explicit.bing.net/th?id=OIP.cysHE...
# 552   https://tse4.mm.bing.net/th?id=OIP.VhogjnWRzUb...
# 227   https://tse3.explicit.bing.net/th?id=OIP.cysHE...
# 243   https://tse4.mm.bing.net/th?id=OIP.0QnXrS2STCJ...
# 221   https://tse3.explicit.bing.net/th?id=OIP.cysHE...
# 424   https://tse1.mm.bing.net/th?id=OIP.KAIEmdZnuss...
# 464   https://tse1.mm.bing.net/th?id=OIP.GNggW5ET63W...
# 153   https://tse1.mm.bing.net/th?id=OIP.KAIEmdZnuss...
#
#                                              clean_blob  sentiment_score  \
# 547   discover case month prepare poster independent...         -0.99700
# 141   slow raise available fall japan quarter share ...          0.93380
# 1034  share celluloid felt communal tour present tru...          0.99810
# 552   delay month jennifer official issue work prosp...         -0.97210
# 227   conflagration ruin sacrilegious stoppard short...          0.99825
# 243   dehumanization vulnerable player funding longi...         -0.99235
# 221   raise behavior lot boat response share frustra...         -0.63405
# 424   mamuju endemic prepare sandy indonesia noisy t...         -0.61680
# 464   win harder send play european attack exchange ...         -0.83460
# 153   inside player interest victim enter basketball...          0.98200
#
#       sensationalism_score  Readability  bias_score  isClickbait         Day  \
# 547               0.245265     9.319450    0.503802            0  2023-12-06
# 141               0.165517     9.044150    0.504626            0  2023-12-08
# 1034              0.326797     8.854036    0.503194            0  2023-12-05
# 552               0.453858     9.539189    0.470722            0  2023-12-06
# 227               0.209570    10.148864    0.496238            0  2023-12-07
# 243               0.445324     9.001553    0.441546            0  2023-12-07
# 221               0.205997     8.376667    0.486267            0  2023-12-07
# 424               0.371543    10.261826    0.479719            0  2023-12-07
# 464               0.234558     9.072305    0.477885            0  2023-12-06
# 153               0.214286     7.957550    0.516775            0  2023-12-07
#
#       combined_score
# 547         0.648871
# 141         0.634242
# 1034        0.632816
# 552         0.632049
# 227         0.628991
# 243         0.628633
# 221         0.628614
# 424         0.625856
# 464         0.625298
# 153         0.621878

# %%
ct_ranked.to_csv("./streamlit/data/CriticalThinker.csv", index=False)

# %%
df["sentiment_score"].describe()
# Out:
# count    2499.000000
# mean        0.061359
# std         0.843027
# min        -0.999750
# 25%        -0.932700
# 50%         0.142400
# 75%         0.955775
# max         0.999650
# Name: sentiment_score, dtype: float64
